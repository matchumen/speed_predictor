# %%
import os, sys
sys.path.insert(1, '../')
import pickle

import pandas as pd
import numpy as np
from torch import nn
from collections import OrderedDict
from speed_predictor import test_model
from speed_predictor.utils import make_dataloader_data
import optuna
import warnings
warnings.filterwarnings("ignore")
from tqdm import tqdm
import matplotlib.pyplot as plt
import disp_utils as du
from utils import MAE
from experimenty.study_3_single_blur_stop.train import define_model
import importlib

import os
import optuna
import pickle
import numpy as np
import matplotlib.pyplot as plt
import utils as utils
from optuna.trial import TrialState as ts
import disp_utils as du

# %%
study_names = [s.study_name for s in optuna.study.get_all_study_summaries("sqlite:///experimenty/00.db")]
study_dirs = os.listdir('experimenty')

print('Studie:')
print('\n'.join(study_names))
print('\nAdresáře:')
print('\n'.join(study_dirs))
# Out:
# Studie:
# 00_MSELoss
# 00_L1Loss_sigmoid
# 04_L1Loss_sigmoid_10_10
# 00_L1Loss_sigmoid_006
# 04_L1Loss_sigmoid_006_10_10
# 04_L1Loss_sigmoid_006_variable_windows
# 04_L1Loss_sigmoid_006_10_10_blurred
# 00_L1Loss_sigmoid_blurred
# 04_L1Loss_sigmoid_006_20_20_blurred
# 04_L1Loss_sigmoid_006_10_10_blurred_stops
# 00_L1Loss_sigmoid_2
# study_single_l1loss_sigmoid_small
# study_single_l1loss_sigmoid_small_blur
# study_single_l1loss_sigmoid_small2
# study_single_l1loss_sigmoid_small_stops
# study_single_l1loss_sigmoid_small_blur_stops
# study_multi_10_10_l1loss_sigmoid_small_blur_stops
#
# Adresáře:
# study_3_single_blur_stop
# study_2_single_stop
# legacy
# study_0_single
# study_4_multi_10_10_blur_stop
# study_1_single_blur
# 00.db

# %%
history = du.load_study_history('study_multi_10_10_l1loss_sigmoid_small_blur_stops', 'experimenty/study_4_multi_10_10_blur_stop', 'sqlite:///experimenty/00.db')
du.plot_study_history(history, k_best=10)

# %%
study_name = 'study_single_l1loss_sigmoid_small_blur_stops'
study_dir = 'study_3_single_blur_stop'

test_results = test_model(
    experiment_dir=os.path.join('experimenty', study_dir),
    study_name=study_name,
    scaler_name=f'scaler_{study_name}.pickle',
    model_fn=define_model,
    blur=True,
    stops=True
)

#with open(f'results/{study_name}.pickle', 'wb') as f:
#    pickle.dump(test_results, f)
# Out:
#   1%|          | 3/307 [00:00<00:14, 21.58it/s]
# {'ACTIVATION_NAME': 'ELU', 'LEARNING_RATE': 4.9164007229137664e-05, 'OPTIMIZER': 'RMSprop'}
# 100%|██████████| 307/307 [00:31<00:00,  9.71it/s]

# %%
#with open(f'results/00_L1Loss_sigmoid_006.pickle', 'rb') as f:
#    test_results = pickle.load(f)

# %%
du.speed_profile(test_results, 169)

# %%
du.mae_mean_clustered(test_results)

# %%
du.mae_std_clustered(test_results)

# %%
du.mae_cars(test_results)

# %%
du.model_to_measured(test_results)

# %%
du.print_res(test_results)
# Out:
# Overall results:
# Mean MAE:          3.281 mps
# Median MAE:        2.902 mps
# Mean MBD:          0.838 mps
# Median MBD:        0.695 mps
# Improvement ratio: 71.7%
#
# Carwise results:
# 004
# Mean MAE:          2.863 mps
# Median MAE:        2.680 mps
# Mean MBD:          1.086 mps
# Median MBD:        1.124 mps
# 005
# Mean MAE:          3.985 mps
# Median MAE:        2.614 mps
# Mean MBD:          0.927 mps
# Median MBD:        0.915 mps
# 002
# Mean MAE:          3.594 mps
# Median MAE:        3.140 mps
# Mean MBD:          -0.327 mps
# Median MBD:        -0.139 mps
# 006
# Mean MAE:          3.244 mps
# Median MAE:        3.055 mps
# Mean MBD:          1.435 mps
# Median MBD:        1.401 mps
#
# Speedwise results

# %%
du.print_res(test_results)
# Out:
# Overall results:
# Mean MAE:          3.818 mps
# Median MAE:        3.099 mps
# Mean MBD:          0.301 mps
# Median MBD:        0.391 mps
# Improvement ratio: 59.3%
#
# Carwise results:
# 004
# Mean MAE:          3.138 mps
# Median MAE:        2.983 mps
# Mean MBD:          0.810 mps
# Median MBD:        0.769 mps
# 005
# Mean MAE:          4.613 mps
# Median MAE:        3.203 mps
# Mean MBD:          0.299 mps
# Median MBD:        0.517 mps
# 002
# Mean MAE:          4.838 mps
# Median MAE:        3.709 mps
# Mean MBD:          -1.571 mps
# Median MBD:        -0.843 mps
# 006
# Mean MAE:          3.481 mps
# Median MAE:        2.822 mps
# Mean MBD:          1.198 mps
# Median MBD:        1.614 mps
#
# Speedwise results

# %%
sorted([(dr[0], dr[1]['pth'], dr[1]['MAE']) for dr in enumerate(test_results['drives_results'])], key=lambda x:x[2])
# Out:
# [(41, 'data/test_dataset/onboard-006-container_00062.csv', 1.2042403517066123),
#  (269,
#   'data/test_dataset/onboard-004-container_00134.csv',
#   1.2927302644185246),
#  (222,
#   'data/test_dataset/onboard-006-container_00136.csv',
#   1.3352793310680822),
#  (29, 'data/test_dataset/onboard-006-container_00032.csv', 1.3604205079587308),
#  (81, 'data/test_dataset/onboard-006-container_00021.csv', 1.3979683833063046),
#  (125,
#   'data/test_dataset/onboard-006-container_00015.csv',
#   1.5021592858757666),
#  (172,
#   'data/test_dataset/onboard-006-container_00113.csv',
#   1.5080162375269832),
#  (169,
#   'data/test_dataset/onboard-006-container_00090.csv',
#   1.5637831959785604),
#  (128, 'data/test_dataset/onboard-005-container_00039.csv', 1.567416717253891),
#  (276, 'data/test_dataset/onboard-006-container_00155.csv', 1.601343008687263),
#  (264,
#   'data/test_dataset/onboard-006-container_00123.csv',
#   1.6193225316497144),
#  (189,
#   'data/test_dataset/onboard-006-container_00003.csv',
#   1.6866598119948075),
#  (153,
#   'data/test_dataset/onboard-004-container_00090.csv',
#   1.7199689199927348),
#  (198,
#   'data/test_dataset/onboard-004-container_00026.csv',
#   1.7296232270880578),
#  (301,
#   'data/test_dataset/onboard-006-container_00034.csv',
#   1.7344128694671077),
#  (79, 'data/test_dataset/onboard-006-container_00124.csv', 1.7541592262176233),
#  (236,
#   'data/test_dataset/onboard-006-container_00143.csv',
#   1.7634904708218113),
#  (135,
#   'data/test_dataset/onboard-006-container_00162.csv',
#   1.7779303710992755),
#  (100,
#   'data/test_dataset/onboard-006-container_00169.csv',
#   1.7852804443159171),
#  (210, 'data/test_dataset/onboard-006-container_00066.csv', 1.788447830393037),
#  (62, 'data/test_dataset/onboard-006-container_00001.csv', 1.80219197011402),
#  (228,
#   'data/test_dataset/onboard-006-container_00014.csv',
#   1.8217948643459025),
#  (177,
#   'data/test_dataset/onboard-004-container_00117.csv',
#   1.9002189373969105),
#  (208,
#   'data/test_dataset/onboard-004-container_00155.csv',
#   1.9116827894277908),
#  (154,
#   'data/test_dataset/onboard-004-container_00101.csv',
#   1.9354938712814325),
#  (149,
#   'data/test_dataset/onboard-006-container_00170.csv',
#   1.9389778798206923),
#  (140,
#   'data/test_dataset/onboard-005-container_00040.csv',
#   1.9523666692665005),
#  (293,
#   'data/test_dataset/onboard-005-container_00075.csv',
#   1.9575106351793696),
#  (268,
#   'data/test_dataset/onboard-004-container_00153.csv',
#   1.9615972932984431),
#  (147,
#   'data/test_dataset/onboard-002-container_00015.csv',
#   1.9990305301764144),
#  (93, 'data/test_dataset/onboard-006-container_00112.csv', 2.0000665127370443),
#  (297, 'data/test_dataset/onboard-002-container_00013.csv', 2.0060244736964),
#  (230,
#   'data/test_dataset/onboard-006-container_00166.csv',
#   2.0101864688338043),
#  (170,
#   'data/test_dataset/onboard-006-container_00099.csv',
#   2.0540150159402697),
#  (73, 'data/test_dataset/onboard-002-container_00080.csv', 2.055549401463243),
#  (22, 'data/test_dataset/onboard-005-container_00087.csv', 2.0669125231464682),
#  (192, 'data/test_dataset/onboard-002-container_00054.csv', 2.068409703235476),
#  (233, 'data/test_dataset/onboard-002-container_00037.csv', 2.092711028641619),
#  (178,
#   'data/test_dataset/onboard-004-container_00021.csv',
#   2.1103826346878485),
#  (212,
#   'data/test_dataset/onboard-004-container_00113.csv',
#   2.1295575015997468),
#  (162, 'data/test_dataset/onboard-006-container_00125.csv', 2.15186887061503),
#  (59, 'data/test_dataset/onboard-004-container_00135.csv', 2.154612214848122),
#  (66, 'data/test_dataset/onboard-006-container_00110.csv', 2.156524357225302),
#  (214,
#   'data/test_dataset/onboard-006-container_00048.csv',
#   2.1686728770591475),
#  (291,
#   'data/test_dataset/onboard-006-container_00139.csv',
#   2.1996422542827427),
#  (306,
#   'data/test_dataset/onboard-006-container_00028.csv',
#   2.2322817136359396),
#  (197, 'data/test_dataset/onboard-004-container_00086.csv', 2.234383897981444),
#  (120, 'data/test_dataset/onboard-006-container_00142.csv', 2.243148058584049),
#  (1, 'data/test_dataset/onboard-004-container_00148.csv', 2.2479587455711205),
#  (241, 'data/test_dataset/onboard-006-container_00054.csv', 2.252534199522058),
#  (136,
#   'data/test_dataset/onboard-004-container_00029.csv',
#   2.2722689939576934),
#  (251,
#   'data/test_dataset/onboard-006-container_00168.csv',
#   2.2800639846008517),
#  (48, 'data/test_dataset/onboard-006-container_00117.csv', 2.281900022141167),
#  (27, 'data/test_dataset/onboard-002-container_00052.csv', 2.3112585829934864),
#  (296,
#   'data/test_dataset/onboard-006-container_00133.csv',
#   2.3172558850451352),
#  (182,
#   'data/test_dataset/onboard-004-container_00100.csv',
#   2.3201089379894086),
#  (203,
#   'data/test_dataset/onboard-004-container_00092.csv',
#   2.3372011402474824),
#  (216, 'data/test_dataset/onboard-006-container_00115.csv', 2.340262982108849),
#  (219,
#   'data/test_dataset/onboard-006-container_00147.csv',
#   2.3481679308754426),
#  (82, 'data/test_dataset/onboard-006-container_00137.csv', 2.3630113860741098),
#  (127,
#   'data/test_dataset/onboard-006-container_00108.csv',
#   2.3685981579771926),
#  (227,
#   'data/test_dataset/onboard-002-container_00051.csv',
#   2.3890649771208223),
#  (55, 'data/test_dataset/onboard-004-container_00137.csv', 2.3946568580985677),
#  (289,
#   'data/test_dataset/onboard-004-container_00105.csv',
#   2.3994835396181897),
#  (4, 'data/test_dataset/onboard-005-container_00062.csv', 2.4170887186033774),
#  (31, 'data/test_dataset/onboard-006-container_00000.csv', 2.4406480412938394),
#  (255,
#   'data/test_dataset/onboard-004-container_00024.csv',
#   2.4469519580590586),
#  (304,
#   'data/test_dataset/onboard-004-container_00149.csv',
#   2.4477861772493266),
#  (299, 'data/test_dataset/onboard-006-container_00041.csv', 2.44807978215477),
#  (151,
#   'data/test_dataset/onboard-004-container_00023.csv',
#   2.4526256142889467),
#  (92, 'data/test_dataset/onboard-004-container_00079.csv', 2.4585300124391947),
#  (180,
#   'data/test_dataset/onboard-004-container_00139.csv',
#   2.4598911547112734),
#  (99, 'data/test_dataset/onboard-006-container_00009.csv', 2.4637963534520284),
#  (87, 'data/test_dataset/onboard-005-container_00026.csv', 2.469164332747437),
#  (24, 'data/test_dataset/onboard-002-container_00027.csv', 2.474963547580288),
#  (40, 'data/test_dataset/onboard-002-container_00077.csv', 2.4752537837203543),
#  (96, 'data/test_dataset/onboard-004-container_00041.csv', 2.4769664730682046),
#  (152, 'data/test_dataset/onboard-004-container_00152.csv', 2.496133340292978),
#  (117, 'data/test_dataset/onboard-006-container_00005.csv', 2.501308755426317),
#  (61, 'data/test_dataset/onboard-004-container_00097.csv', 2.5111816700106053),
#  (234,
#   'data/test_dataset/onboard-002-container_00124.csv',
#   2.5113764184975103),
#  (195,
#   'data/test_dataset/onboard-004-container_00078.csv',
#   2.5170865751255445),
#  (200,
#   'data/test_dataset/onboard-002-container_00086.csv',
#   2.5235336247569897),
#  (123,
#   'data/test_dataset/onboard-006-container_00149.csv',
#   2.5396705438297507),
#  (11, 'data/test_dataset/onboard-004-container_00044.csv', 2.5405016743884534),
#  (160, 'data/test_dataset/onboard-004-container_00150.csv', 2.551770093704825),
#  (218, 'data/test_dataset/onboard-004-container_00019.csv', 2.551972428257743),
#  (35, 'data/test_dataset/onboard-006-container_00091.csv', 2.554042175133057),
#  (67, 'data/test_dataset/onboard-004-container_00145.csv', 2.558468242971261),
#  (39, 'data/test_dataset/onboard-006-container_00174.csv', 2.5634398309587323),
#  (58, 'data/test_dataset/onboard-004-container_00010.csv', 2.583009382295575),
#  (139, 'data/test_dataset/onboard-006-container_00089.csv', 2.584679712994786),
#  (34, 'data/test_dataset/onboard-004-container_00091.csv', 2.599494179970087),
#  (209,
#   'data/test_dataset/onboard-006-container_00008.csv',
#   2.6148061794776885),
#  (115,
#   'data/test_dataset/onboard-004-container_00034.csv',
#   2.6177852747980386),
#  (83, 'data/test_dataset/onboard-002-container_00057.csv', 2.6276593535102277),
#  (242,
#   'data/test_dataset/onboard-005-container_00011.csv',
#   2.6461727608791827),
#  (52, 'data/test_dataset/onboard-006-container_00098.csv', 2.6484360957411432),
#  (134,
#   'data/test_dataset/onboard-006-container_00121.csv',
#   2.6505746050073205),
#  (179,
#   'data/test_dataset/onboard-004-container_00132.csv',
#   2.6585215535472013),
#  (190, 'data/test_dataset/onboard-002-container_00064.csv', 2.670166982195523),
#  (85, 'data/test_dataset/onboard-004-container_00094.csv', 2.670938257674029),
#  (121, 'data/test_dataset/onboard-006-container_00043.csv', 2.673666080586027),
#  (132, 'data/test_dataset/onboard-004-container_00082.csv', 2.723290770931872),
#  (303, 'data/test_dataset/onboard-004-container_00051.csv', 2.737608339673953),
#  (263,
#   'data/test_dataset/onboard-005-container_00078.csv',
#   2.7379619149987953),
#  (2, 'data/test_dataset/onboard-005-container_00081.csv', 2.7397956434651283),
#  (187, 'data/test_dataset/onboard-004-container_00060.csv', 2.757171061891879),
#  (89, 'data/test_dataset/onboard-004-container_00039.csv', 2.7678299287066896),
#  (63, 'data/test_dataset/onboard-004-container_00075.csv', 2.7678617576193347),
#  (282,
#   'data/test_dataset/onboard-004-container_00008.csv',
#   2.7714519618760463),
#  (130,
#   'data/test_dataset/onboard-006-container_00013.csv',
#   2.7803402495305996),
#  (253, 'data/test_dataset/onboard-004-container_00036.csv', 2.782933755743388),
#  (20, 'data/test_dataset/onboard-002-container_00084.csv', 2.7848008968684277),
#  (185, 'data/test_dataset/onboard-004-container_00128.csv', 2.787202631826356),
#  (110,
#   'data/test_dataset/onboard-006-container_00118.csv',
#   2.8041472323137016),
#  (215, 'data/test_dataset/onboard-002-container_00107.csv', 2.812773913771468),
#  (302,
#   'data/test_dataset/onboard-006-container_00132.csv',
#   2.8223971618750916),
#  (201, 'data/test_dataset/onboard-006-container_00042.csv', 2.822443785833815),
#  (56, 'data/test_dataset/onboard-006-container_00173.csv', 2.8244243379407146),
#  (220, 'data/test_dataset/onboard-006-container_00012.csv', 2.857464823039955),
#  (225,
#   'data/test_dataset/onboard-005-container_00005.csv',
#   2.8704949969959404),
#  (237,
#   'data/test_dataset/onboard-006-container_00101.csv',
#   2.8719068321477956),
#  (161, 'data/test_dataset/onboard-005-container_00009.csv', 2.874527545752537),
#  (257,
#   'data/test_dataset/onboard-002-container_00014.csv',
#   2.8819466514137844),
#  (113,
#   'data/test_dataset/onboard-004-container_00050.csv',
#   2.8869620003792913),
#  (25, 'data/test_dataset/onboard-002-container_00000.csv', 2.8895777085855348),
#  (156,
#   'data/test_dataset/onboard-002-container_00111.csv',
#   2.8919375850503037),
#  (167, 'data/test_dataset/onboard-004-container_00016.csv', 2.893664007487201),
#  (33, 'data/test_dataset/onboard-004-container_00038.csv', 2.8947329927238865),
#  (38, 'data/test_dataset/onboard-005-container_00015.csv', 2.8954022104808472),
#  (217,
#   'data/test_dataset/onboard-004-container_00000.csv',
#   2.8974596199603084),
#  (7, 'data/test_dataset/onboard-006-container_00088.csv', 2.903009646691629),
#  (90, 'data/test_dataset/onboard-002-container_00081.csv', 2.9051938552119534),
#  (174, 'data/test_dataset/onboard-006-container_00058.csv', 2.911333550431331),
#  (77, 'data/test_dataset/onboard-006-container_00150.csv', 2.9175564746664957),
#  (103, 'data/test_dataset/onboard-006-container_00083.csv', 2.928181792770086),
#  (71, 'data/test_dataset/onboard-002-container_00062.csv', 2.946690437744868),
#  (91, 'data/test_dataset/onboard-004-container_00006.csv', 2.9541524355851565),
#  (261,
#   'data/test_dataset/onboard-006-container_00061.csv',
#   2.9695736146461553),
#  (106, 'data/test_dataset/onboard-004-container_00002.csv', 2.978684304774821),
#  (278,
#   'data/test_dataset/onboard-006-container_00160.csv',
#   2.9867075630935895),
#  (181, 'data/test_dataset/onboard-004-container_00017.csv', 2.98737598947651),
#  (270, 'data/test_dataset/onboard-004-container_00031.csv', 2.990244378821338),
#  (238, 'data/test_dataset/onboard-004-container_00011.csv', 2.999694587366218),
#  (199,
#   'data/test_dataset/onboard-002-container_00112.csv',
#   3.0090081544531824),
#  (258,
#   'data/test_dataset/onboard-005-container_00074.csv',
#   3.0230892085686616),
#  (32, 'data/test_dataset/onboard-004-container_00138.csv', 3.033004818138113),
#  (105, 'data/test_dataset/onboard-002-container_00003.csv', 3.03301449519687),
#  (9, 'data/test_dataset/onboard-004-container_00133.csv', 3.0551155950431137),
#  (271, 'data/test_dataset/onboard-005-container_00094.csv', 3.057509990327323),
#  (155, 'data/test_dataset/onboard-004-container_00003.csv', 3.066210626215641),
#  (265,
#   'data/test_dataset/onboard-006-container_00095.csv',
#   3.0881149826976784),
#  (76, 'data/test_dataset/onboard-002-container_00026.csv', 3.0992877407865143),
#  (211, 'data/test_dataset/onboard-006-container_00053.csv', 3.103401960861832),
#  (188, 'data/test_dataset/onboard-004-container_00157.csv', 3.10631334063782),
#  (86, 'data/test_dataset/onboard-006-container_00163.csv', 3.1084554751245603),
#  (114, 'data/test_dataset/onboard-002-container_00102.csv', 3.108686782046876),
#  (223, 'data/test_dataset/onboard-004-container_00143.csv', 3.113835743457855),
#  (57, 'data/test_dataset/onboard-002-container_00106.csv', 3.11917259516879),
#  (266,
#   'data/test_dataset/onboard-005-container_00083.csv',
#   3.1203598908096466),
#  (44, 'data/test_dataset/onboard-002-container_00016.csv', 3.1228030148852417),
#  (118, 'data/test_dataset/onboard-002-container_00066.csv', 3.12912976568205),
#  (194,
#   'data/test_dataset/onboard-004-container_00007.csv',
#   3.1297464230796512),
#  (133,
#   'data/test_dataset/onboard-002-container_00123.csv',
#   3.1309779209444017),
#  (231, 'data/test_dataset/onboard-004-container_00071.csv', 3.133083535454769),
#  (274, 'data/test_dataset/onboard-004-container_00046.csv', 3.133756556121725),
#  (143,
#   'data/test_dataset/onboard-006-container_00038.csv',
#   3.1392143898427647),
#  (75, 'data/test_dataset/onboard-004-container_00067.csv', 3.1434801955033986),
#  (145,
#   'data/test_dataset/onboard-004-container_00070.csv',
#   3.1446225751960397),
#  (144,
#   'data/test_dataset/onboard-006-container_00035.csv',
#   3.1453399157771864),
#  (290, 'data/test_dataset/onboard-006-container_00135.csv', 3.146535109235761),
#  (232,
#   'data/test_dataset/onboard-004-container_00096.csv',
#   3.1530446905091947),
#  (283,
#   'data/test_dataset/onboard-004-container_00073.csv',
#   3.1607236593813477),
#  (69, 'data/test_dataset/onboard-004-container_00059.csv', 3.207450252011274),
#  (28, 'data/test_dataset/onboard-002-container_00108.csv', 3.215127211711543),
#  (43, 'data/test_dataset/onboard-002-container_00030.csv', 3.2153553848874443),
#  (104,
#   'data/test_dataset/onboard-004-container_00142.csv',
#   3.2168966132915724),
#  (247, 'data/test_dataset/onboard-002-container_00079.csv', 3.233370104228222),
#  (249, 'data/test_dataset/onboard-004-container_00130.csv', 3.236125268582078),
#  (260, 'data/test_dataset/onboard-004-container_00120.csv', 3.241031671181907),
#  (72, 'data/test_dataset/onboard-002-container_00044.csv', 3.247433660756422),
#  (246,
#   'data/test_dataset/onboard-006-container_00082.csv',
#   3.2699590240103094),
#  (19, 'data/test_dataset/onboard-004-container_00124.csv', 3.2780886361373622),
#  (213,
#   'data/test_dataset/onboard-005-container_00059.csv',
#   3.2849663653432835),
#  (101, 'data/test_dataset/onboard-004-container_00064.csv', 3.285095407101167),
#  (6, 'data/test_dataset/onboard-006-container_00152.csv', 3.292217560520735),
#  (173, 'data/test_dataset/onboard-004-container_00115.csv', 3.310509048490196),
#  (122,
#   'data/test_dataset/onboard-004-container_00012.csv',
#   3.3164590224670167),
#  (50, 'data/test_dataset/onboard-004-container_00072.csv', 3.3188377434982494),
#  (68, 'data/test_dataset/onboard-002-container_00078.csv', 3.3279753529835454),
#  (184,
#   'data/test_dataset/onboard-004-container_00052.csv',
#   3.3305273328416094),
#  (285,
#   'data/test_dataset/onboard-004-container_00015.csv',
#   3.3374686540676444),
#  (16, 'data/test_dataset/onboard-004-container_00001.csv', 3.3462647304917343),
#  (129,
#   'data/test_dataset/onboard-004-container_00127.csv',
#   3.3493438365947714),
#  (186,
#   'data/test_dataset/onboard-004-container_00035.csv',
#   3.3547021239255184),
#  (171, 'data/test_dataset/onboard-002-container_00021.csv', 3.376252307177364),
#  (84, 'data/test_dataset/onboard-006-container_00046.csv', 3.416062473999948),
#  (126,
#   'data/test_dataset/onboard-002-container_00022.csv',
#   3.4473593988768134),
#  (262, 'data/test_dataset/onboard-002-container_00059.csv', 3.50714092292595),
#  (60, 'data/test_dataset/onboard-005-container_00070.csv', 3.516325417151747),
#  (107,
#   'data/test_dataset/onboard-002-container_00023.csv',
#   3.5311189757513315),
#  (111,
#   'data/test_dataset/onboard-005-container_00068.csv',
#   3.5390035854453092),
#  (146, 'data/test_dataset/onboard-006-container_00164.csv', 3.556766780891872),
#  (119, 'data/test_dataset/onboard-006-container_00040.csv', 3.56711186504886),
#  (37, 'data/test_dataset/onboard-006-container_00019.csv', 3.5749638750994857),
#  (239,
#   'data/test_dataset/onboard-004-container_00112.csv',
#   3.6004968143757683),
#  (14, 'data/test_dataset/onboard-004-container_00065.csv', 3.602927206680689),
#  (191, 'data/test_dataset/onboard-005-container_00038.csv', 3.646355686972231),
#  (252,
#   'data/test_dataset/onboard-006-container_00063.csv',
#   3.6722631424749133),
#  (164,
#   'data/test_dataset/onboard-002-container_00075.csv',
#   3.6859469785121743),
#  (280,
#   'data/test_dataset/onboard-005-container_00076.csv',
#   3.7161451381321857),
#  (138, 'data/test_dataset/onboard-002-container_00104.csv', 3.731933265174763),
#  (15, 'data/test_dataset/onboard-002-container_00089.csv', 3.7349052402286813),
#  (287,
#   'data/test_dataset/onboard-006-container_00151.csv',
#   3.7669689645512334),
#  (94, 'data/test_dataset/onboard-002-container_00133.csv', 3.7814508821688615),
#  (98, 'data/test_dataset/onboard-006-container_00078.csv', 3.7925242517760394),
#  (5, 'data/test_dataset/onboard-002-container_00092.csv', 3.7928282810377123),
#  (295,
#   'data/test_dataset/onboard-006-container_00114.csv',
#   3.7960255016796456),
#  (157,
#   'data/test_dataset/onboard-006-container_00096.csv',
#   3.8086644917601467),
#  (298,
#   'data/test_dataset/onboard-002-container_00031.csv',
#   3.8226768132372175),
#  (80, 'data/test_dataset/onboard-004-container_00107.csv', 3.825786948476222),
#  (124,
#   'data/test_dataset/onboard-006-container_00018.csv',
#   3.8302950390055046),
#  (300, 'data/test_dataset/onboard-004-container_00033.csv', 3.862585506735124),
#  (150,
#   'data/test_dataset/onboard-004-container_00004.csv',
#   3.8784314099422663),
#  (112,
#   'data/test_dataset/onboard-002-container_00114.csv',
#   3.8805919080025246),
#  (26, 'data/test_dataset/onboard-004-container_00066.csv', 3.9074986610568727),
#  (244,
#   'data/test_dataset/onboard-004-container_00063.csv',
#   3.9334338518272145),
#  (183, 'data/test_dataset/onboard-006-container_00002.csv', 3.951494794121121),
#  (176, 'data/test_dataset/onboard-005-container_00037.csv', 4.006312378908165),
#  (163, 'data/test_dataset/onboard-004-container_00114.csv', 4.071278944189074),
#  (95, 'data/test_dataset/onboard-004-container_00037.csv', 4.083976738007796),
#  (159, 'data/test_dataset/onboard-006-container_00064.csv', 4.109780421099663),
#  (53, 'data/test_dataset/onboard-004-container_00058.csv', 4.115164016308205),
#  (142, 'data/test_dataset/onboard-002-container_00048.csv', 4.125010702481204),
#  (108, 'data/test_dataset/onboard-002-container_00128.csv', 4.132854884842999),
#  (18, 'data/test_dataset/onboard-002-container_00018.csv', 4.213447870460517),
#  (248, 'data/test_dataset/onboard-002-container_00073.csv', 4.214610376997112),
#  (165,
#   'data/test_dataset/onboard-006-container_00052.csv',
#   4.2281216957077605),
#  (116, 'data/test_dataset/onboard-006-container_00086.csv', 4.276080954354641),
#  (256,
#   'data/test_dataset/onboard-002-container_00039.csv',
#   4.2789661695547725),
#  (254, 'data/test_dataset/onboard-002-container_00119.csv', 4.300624219911807),
#  (259, 'data/test_dataset/onboard-004-container_00054.csv', 4.305775479661582),
#  (131, 'data/test_dataset/onboard-005-container_00082.csv', 4.322409730648464),
#  (272,
#   'data/test_dataset/onboard-004-container_00156.csv',
#   4.3509078796221505),
#  (275, 'data/test_dataset/onboard-004-container_00025.csv', 4.427823006780987),
#  (224, 'data/test_dataset/onboard-002-container_00040.csv', 4.427848140204751),
#  (70, 'data/test_dataset/onboard-002-container_00006.csv', 4.480989257728875),
#  (21, 'data/test_dataset/onboard-004-container_00049.csv', 4.5272448832208685),
#  (226, 'data/test_dataset/onboard-002-container_00127.csv', 4.540133075097014),
#  (288, 'data/test_dataset/onboard-006-container_00093.csv', 4.618388131612822),
#  (141, 'data/test_dataset/onboard-006-container_00049.csv', 4.66839814029331),
#  (78, 'data/test_dataset/onboard-006-container_00060.csv', 4.691436133300169),
#  (168, 'data/test_dataset/onboard-006-container_00153.csv', 4.777049907016995),
#  (30, 'data/test_dataset/onboard-006-container_00067.csv', 4.779923695509255),
#  (273, 'data/test_dataset/onboard-004-container_00062.csv', 4.801003843279952),
#  (235, 'data/test_dataset/onboard-002-container_00121.csv', 4.817798055583873),
#  (42, 'data/test_dataset/onboard-005-container_00065.csv', 5.08817570339237),
#  (64, 'data/test_dataset/onboard-002-container_00007.csv', 5.098965028281655),
#  (17, 'data/test_dataset/onboard-002-container_00093.csv', 5.1104730844405735),
#  (221, 'data/test_dataset/onboard-002-container_00096.csv', 5.13068003827254),
#  (88, 'data/test_dataset/onboard-004-container_00083.csv', 5.356872775195088),
#  (13, 'data/test_dataset/onboard-006-container_00036.csv', 5.523840942939064),
#  (3, 'data/test_dataset/onboard-005-container_00069.csv', 5.654300548719754),
#  (202, 'data/test_dataset/onboard-002-container_00082.csv', 5.671971911337601),
#  (284, 'data/test_dataset/onboard-006-container_00072.csv', 5.813492121542623),
#  (267, 'data/test_dataset/onboard-002-container_00045.csv', 5.86517650071256),
#  (294, 'data/test_dataset/onboard-005-container_00016.csv', 5.928080541574034),
#  (250, 'data/test_dataset/onboard-002-container_00099.csv', 6.012622273537491),
#  (229, 'data/test_dataset/onboard-004-container_00057.csv', 6.04353222206529),
#  (204, 'data/test_dataset/onboard-002-container_00009.csv', 6.139488843959123),
#  (206,
#   'data/test_dataset/onboard-005-container_00063.csv',
#   6.1522385946461275),
#  (277, 'data/test_dataset/onboard-002-container_00135.csv', 6.166163155887569),
#  (286, 'data/test_dataset/onboard-006-container_00075.csv', 6.200419864575035),
#  (243, 'data/test_dataset/onboard-002-container_00122.csv', 6.232467513059162),
#  (23, 'data/test_dataset/onboard-006-container_00069.csv', 6.3748082631130645),
#  (0, 'data/test_dataset/onboard-004-container_00129.csv', 6.4018530012480745),
#  (137, 'data/test_dataset/onboard-006-container_00065.csv', 6.496227723072313),
#  (166, 'data/test_dataset/onboard-002-container_00053.csv', 6.660943896599733),
#  (279, 'data/test_dataset/onboard-002-container_00094.csv', 6.734195536764043),
#  (36, 'data/test_dataset/onboard-006-container_00068.csv', 6.883272070250588),
#  (8, 'data/test_dataset/onboard-006-container_00085.csv', 6.955948710528889),
#  (74, 'data/test_dataset/onboard-006-container_00092.csv', 7.055364797644091),
#  (45, 'data/test_dataset/onboard-004-container_00042.csv', 7.212907552166667),
#  (97, 'data/test_dataset/onboard-002-container_00019.csv', 7.324411919374255),
#  (245, 'data/test_dataset/onboard-006-container_00084.csv', 7.492679052850904),
#  (10, 'data/test_dataset/onboard-006-container_00076.csv', 7.50169574432796),
#  (175, 'data/test_dataset/onboard-002-container_00120.csv', 7.649785161725799),
#  (305, 'data/test_dataset/onboard-002-container_00036.csv', 8.200772725662986),
#  (240, 'data/test_dataset/onboard-006-container_00073.csv', 8.20126977520576),
#  (148, 'data/test_dataset/onboard-006-container_00080.csv', 8.494255089804977),
#  (196, 'data/test_dataset/onboard-004-container_00136.csv', 8.523106361637232),
#  (292, 'data/test_dataset/onboard-002-container_00024.csv', 8.677545707852467),
#  (54, 'data/test_dataset/onboard-005-container_00020.csv', 8.763426404633833),
#  (281, 'data/test_dataset/onboard-005-container_00092.csv', 9.566628797192267),
#  (12, 'data/test_dataset/onboard-006-container_00081.csv', 10.11241745842621),
#  (158,
#   'data/test_dataset/onboard-002-container_00069.csv',
#   10.146427583476152),
#  (47, 'data/test_dataset/onboard-002-container_00072.csv', 10.596734609676862),
#  (205,
#   'data/test_dataset/onboard-002-container_00020.csv',
#   11.154213372241774),
#  (193,
#   'data/test_dataset/onboard-002-container_00041.csv',
#   12.078877383862805),
#  (102,
#   'data/test_dataset/onboard-002-container_00046.csv',
#   12.263798812560179),
#  (207,
#   'data/test_dataset/onboard-006-container_00074.csv',
#   12.438274167411976),
#  (109, 'data/test_dataset/onboard-006-container_00070.csv', 14.06386308979831),
#  (51, 'data/test_dataset/onboard-005-container_00019.csv', 15.83539780826134),
#  (49, 'data/test_dataset/onboard-005-container_00023.csv', 16.96939464340928),
#  (65, 'data/test_dataset/onboard-002-container_00132.csv', 18.050812983691372),
#  (46, 'data/test_dataset/onboard-002-container_00131.csv', 21.563248077941143)]

# %%
cars = list(test_results['car_results'].keys())
data = {}
for d in test_results['drives_results']:
    car_id = d['pth'].split('-')[1]
    if car_id not in data.keys():
        data[car_id] = []
    data[car_id].append(d['MAE'])
    
y = [data[k] for k in data.keys()]
x = list(data.keys())

fig, ax = plt.subplots()
counts, bins, patches = plt.hist(y, label=x, bins=np.arange(17))
ax.set_xticks(bins)

plt.title('Histogram středních absolutních chyb podle vozidel')
plt.xlabel('Střední absolutní chyba')  
plt.ylabel('Četnost')
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6d572f133dce> in <module>
# ----> 1 cars = list(test_results['car_results'].keys())
#       2 data = {}
#       3 for d in test_results['drives_results']:
#       4     car_id = d['pth'].split('-')[1]
#       5     if car_id not in data.keys():
#
# NameError: name 'test_results' is not defined
